# %%
import cv2

from temperature_detection import *

# %%
path_of_test_image = 'C:/Users/ELIAV/Downloads/parabola_00101.png'

# %%
# load sample_image
x = LoaderEnum.ImageLoader().load(path_of_test_image)

# display image
import matplotlib.pyplot as plt
print('Sample image:')
plt.imshow(x, cmap='gray', vmin=0, vmax=1)
cv2.waitKey(0)
plt.show()
# Out:
# Sample image:

# %%
from tensorflow import keras

model_for_evaluation_path = './logs/20210627-133844/model/'
model = keras.models.load_model(model_for_evaluation_path)

# %%
class_names = ['line', 'parabola', 'sine']
print('The predicted class is:', class_names[np.argmax(model.predict(np.expand_dims([x], -1)))])
# Out:
# The predicted class is: parabola
